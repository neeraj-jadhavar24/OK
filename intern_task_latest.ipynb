# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt

import seaborn as sns
# %matplotlib inline

# %%
df= pd.read_csv('data_fs.csv',index_col=0)
df_credit=pd.read_csv('data_fs.csv',index_col=0)
df.head()
# Out:
#    Age     Sex  Job  ... Credit amount Duration              Purpose
# 0   67    male    2  ...          1169        6             radio/TV
# 1   22  female    2  ...          5951       48             radio/TV
# 2   49    male    1  ...          2096       12            education
# 3   45    male    2  ...          7882       42  furniture/equipment
# 4   53    male    2  ...          4870       24                  car
#
# [5 rows x 9 columns]

# %%
df_credit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               1000 non-null   int64
#  1   Sex               1000 non-null   object
#  2   Job               1000 non-null   int64
#  3   Housing           1000 non-null   object
#  4   Saving accounts   817 non-null    object
#  5   Checking account  606 non-null    object
#  6   Credit amount     1000 non-null   int64
#  7   Duration          1000 non-null   int64
#  8   Purpose           1000 non-null   object
# dtypes: int64(4), object(5)
# memory usage: 78.1+ KB

# %%
print(df.nunique())
# Out:
# Age                  53
# Sex                   2
# Job                   4
# Housing               3
# Saving accounts       4
# Checking account      3
# Credit amount       921
# Duration             33
# Purpose               8
# dtype: int64

# %% [markdown]
# # **Exploring continuous variable Age**

# %%
plt.hist(df['Age'], 26,density=True)
plt.show()

# %%
a=sns.distplot(df["Age"], 
             color="r")
a.set_title("Age Distribuition", fontsize=15)
a.set_xlabel("Age")
a.set_xlabel("Frequency")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Frequency')

# %% [markdown]
# ### **Categorical Variable for Age to visualise with boxplot**

# %%
interval = (18, 25, 35, 60, 120)

cats = ['Student', 'Young', 'Adult', 'Senior']
df_credit["Age_cat"] = pd.cut(df_credit.Age, interval, labels=cats)

# %%
sns.boxplot(y=df["Credit amount"],
    x=df["Age_cat"])

# %% [markdown]
# # **Distribuition of Housing own and rent**

# %%
plt.bar(df_credit["Housing"].value_counts().index.values,df_credit["Housing"].value_counts().values)
plt.title('Housing distribution')
plt.show()
print(df['Housing'].value_counts())
# Out:
# own     713
# rent    179
# free    108
# Name: Housing, dtype: int64

# %%
a=sns.distplot(df["Credit amount"], 
             color="b")
a.set_title("Credit amount", fontsize=15)

a.set_xlabel("Frequency")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Frequency')

# %% [markdown]
# **Distribuition of Credit Amount by Housing**

# %%
sns.violinplot(x=df['Credit amount'],y=df['Housing']
            )

# %% [markdown]
# # **Sex Count**

# %%
plt.bar(df_credit["Sex"].value_counts().index.values,df_credit["Sex"].value_counts().values)
plt.show()
print(df['Sex'].value_counts())
# Out:
# male      690
# female    310
# Name: Sex, dtype: int64

# %% [markdown]
# ### **Credit Amount by Sex**

# %%
sns.boxplot(y=df["Credit amount"],
    x=df["Sex"])

# %% [markdown]
# # **Job Distribution**

# %%
plt.bar(df_credit["Job"].value_counts().index.values,df_credit["Job"].value_counts().values)
plt.title('Job Distribution')
plt.show()
print(df['Job'].value_counts())
# Out:
# 2    630
# 1    200
# 3    148
# 0     22
# Name: Job, dtype: int64

# %% [markdown]
# ## **Job distribution with Credit amount**

# %%
sns.boxplot(y=df["Credit amount"],
    x=df["Job"])

# %%
sns.violinplot(y=df['Age'],x=df['Job']
            )

# %% [markdown]
# ## **Distribution of Credit Amount**

# %%
x1 = np.log(df['Credit amount'])
a1=sns.distplot(x1, 
             color="y")
a1.set_title("Credit amount", fontsize=15)

a1.set_xlabel("Frequency")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Frequency')

# %% [markdown]
# ### **Distruibution of Saving accounts**

# %%
plt.bar(df_credit["Saving accounts"].value_counts().index.values,df_credit["Saving accounts"].value_counts().values)
plt.title('Saving account')
plt.show()
print(df['Saving accounts'].value_counts())
# Out:
# little        603
# moderate      103
# quite rich     63
# rich           48
# Name: Saving accounts, dtype: int64

# %%
sns.boxplot(y=df["Credit amount"],
    x=df["Saving accounts"])

# %%
sns.boxplot(y=df["Age"],
    x=df["Saving accounts"])

# %% [markdown]
# ## **Distribution of Purpose**

# %%
plt.bar(df_credit["Purpose"].value_counts().index.values,df_credit["Purpose"].value_counts().values)
plt.title('Purpose')

plt.show()
print(df['Purpose'].value_counts())
# Out:
# car                    337
# radio/TV               280
# furniture/equipment    181
# business                97
# education               59
# repairs                 22
# vacation/others         12
# domestic appliances     12
# Name: Purpose, dtype: int64

# %%
plt.figure(figsize = (12,8))
sns.boxplot(y=df["Credit amount"],
    x=df["Purpose"])
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text major ticklabel objects>)

# %%
sns.violinplot(y=df['Age'],x=df['Purpose']
            )
plt.xticks(rotation=50)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text major ticklabel objects>)

# %%
sns.boxplot(y=df["Age"],
    x=df["Purpose"])
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4, 5, 6, 7]), <a list of 8 Text major ticklabel objects>)

# %% [markdown]
# ## **Duration distribution**

# %%
a1=sns.distplot(df['Duration'], 
             color="b")
a1.set_title("Duration", fontsize=15)

a1.set_xlabel("Frequency")
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 0, 'Frequency')

# %% [markdown]
# ## **Checking account**

# %%
plt.bar(df_credit["Checking account"].value_counts().index.values,df_credit["Checking account"].value_counts().values)
plt.title('Checking account')

plt.show()
print(df['Checking account'].value_counts())
# Out:
# little      274
# moderate    269
# rich         63
# Name: Checking account, dtype: int64

# %%
plt.figure(figsize = (8,8))
sns.boxplot(y=df["Credit amount"],
    x=df["Checking account"])

# %%
sns.boxplot(y=df["Age"],
    x=df["Checking account"])

# %% [markdown]
# ## **Crosstabs**

# %%
print(pd.crosstab(df_credit.Sex, df_credit.Job))
# Out:
# Job      0    1    2    3
# Sex
# female  12   64  197   37
# male    10  136  433  111

# %%
print(pd.crosstab(df_credit.Sex, df_credit.Housing))
# Out:
# Housing  free  own  rent
# Sex
# female     19  196    95
# male       89  517    84

# %%
pd.crosstab(df_credit.Housing, df_credit.Job).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
# #T_2ce95062_b738_11eb_ba80_0242ac1c0002row0_col0,#T_2ce95062_b738_11eb_ba80_0242ac1c0002row0_col1,#T_2ce95062_b738_11eb_ba80_0242ac1c0002row0_col2,#T_2ce95062_b738_11eb_ba80_0242ac1c0002row2_col3{
#             background-color:  #f3f0f0;
#             color:  #000000;
#         }#T_2ce95062_b738_11eb_ba80_0242ac1c0002row0_col3{
#             background-color:  #f5c8c8;
#             color:  #000000;
#         }#T_2ce95062_b738_11eb_ba80_0242ac1c0002row1_col0,#T_2ce95062_b738_11eb_ba80_0242ac1c0002row1_col1,#T_2ce95062_b738_11eb_ba80_0242ac1c0002row1_col2,#T_2ce95062_b738_11eb_ba80_0242ac1c0002row1_col3{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_2ce95062_b738_11eb_ba80_0242ac1c0002row2_col0{
#             background-color:  #f4d6d6;
#             color:  #000000;
#         }#T_2ce95062_b738_11eb_ba80_0242ac1c0002row2_col1{
#             background-color:  #f5bfbf;
#             color:  #000000;
# ...

# %%
date_int = ["Purpose", 'Sex']
cm = sns.light_palette("red", as_cmap=True)
pd.crosstab(df_credit[date_int[0]], df_credit[date_int[1]]).style.background_gradient(cmap = cm)
# Out:
# <style  type="text/css" >
# #T_0d8fd196_b738_11eb_ba80_0242ac1c0002row0_col0{
#             background-color:  #f5c6c6;
#             color:  #000000;
#         }#T_0d8fd196_b738_11eb_ba80_0242ac1c0002row0_col1{
#             background-color:  #f7a8a7;
#             color:  #000000;
#         }#T_0d8fd196_b738_11eb_ba80_0242ac1c0002row1_col0,#T_0d8fd196_b738_11eb_ba80_0242ac1c0002row1_col1{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_0d8fd196_b738_11eb_ba80_0242ac1c0002row2_col0{
#             background-color:  #f3e8e8;
#             color:  #000000;
#         }#T_0d8fd196_b738_11eb_ba80_0242ac1c0002row2_col1,#T_0d8fd196_b738_11eb_ba80_0242ac1c0002row7_col0{
#             background-color:  #f3f0f0;
#             color:  #000000;
#         }#T_0d8fd196_b738_11eb_ba80_0242ac1c0002row3_col0{
#             background-color:  #f6b8b8;
#             color:  #000000;
#         }#T_0d8fd196_b738_11eb_ba80_0242ac1c0002row3_col1{
# ...

# %%
print("Purpose : ",df_credit.Purpose.unique())
print("Sex : ",df_credit.Sex.unique())
print("Housing : ",df_credit.Housing.unique())
print("Saving accounts : ",df_credit['Saving accounts'].unique())

print("Checking account : ",df_credit['Checking account'].unique())
print("Aget_cat : ",df_credit['Age_cat'].unique())
# Out:
# Purpose :  ['radio/TV' 'education' 'furniture/equipment' 'car' 'business'
#  'domestic appliances' 'repairs' 'vacation/others']
# Sex :  ['male' 'female']
# Housing :  ['own' 'free' 'rent']
# Saving accounts :  [nan 'little' 'quite rich' 'rich' 'moderate']
# Checking account :  ['little' 'moderate' nan 'rich']
# Aget_cat :  ['Senior', 'Student', 'Adult', 'Young']
# Categories (4, object): ['Student' < 'Young' < 'Adult' < 'Senior']

# %% [markdown]
# ### **Feature enginnering**

# %%
def one_hot_encoder(df, nan_as_category = False):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category, drop_first=True)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# %%
df_credit['Saving accounts'] = df_credit['Saving accounts'].fillna('no_inf')
df_credit['Checking account'] = df_credit['Checking account'].fillna('no_inf')

# %%
df_credit.columns
# Out:
# Index(['Age', 'Job', 'Credit amount', 'Duration', 'Purpose_car',
#        'Purpose_domestic appliances', 'Purpose_education',
#        'Purpose_furniture/equipment', 'Purpose_radio/TV', 'Purpose_repairs',
#        'Purpose_vacation/others', 'Sex_male', 'Housing_own', 'Housing_rent',
#        'Savings_moderate', 'Savings_no_inf', 'Savings_quite rich',
#        'Savings_rich', 'Check_moderate', 'Check_no_inf', 'Check_rich',
#        'Age_cat_Young', 'Age_cat_Adult', 'Age_cat_Senior'],
#       dtype='object')

# %%
#Purpose to Dummies Variable
df_credit = df_credit.merge(pd.get_dummies(df_credit.Purpose, drop_first=True, prefix='Purpose'), left_index=True, right_index=True)
#Sex feature in dummies
df_credit = df_credit.merge(pd.get_dummies(df_credit.Sex, drop_first=True, prefix='Sex'), left_index=True, right_index=True)
# Housing get dummies
df_credit = df_credit.merge(pd.get_dummies(df_credit.Housing, drop_first=True, prefix='Housing'), left_index=True, right_index=True)
# Housing get Saving Accounts
df_credit = df_credit.merge(pd.get_dummies(df_credit["Saving accounts"], drop_first=True, prefix='Savings'), left_index=True, right_index=True)
# Housing get Risk

# Housing get Checking Account
df_credit = df_credit.merge(pd.get_dummies(df_credit["Checking account"], drop_first=True, prefix='Check'), left_index=True, right_index=True)
# Housing get Age categorical
df_credit = df_credit.merge(pd.get_dummies(df_credit["Age_cat"], drop_first=True, prefix='Age_cat'), left_index=True, right_index=True)

# %%
df_credit.head()
# Out:
#    Age     Sex  Job  ... Age_cat_Young Age_cat_Adult Age_cat_Senior
# 0   67    male    2  ...             0             0              1
# 1   22  female    2  ...             0             0              0
# 2   49    male    1  ...             0             1              0
# 3   45    male    2  ...             0             1              0
# 4   53    male    2  ...             0             1              0
#
# [5 rows x 47 columns]

# %%
del df_credit["Saving accounts"]
del df_credit["Checking account"]
del df_credit["Purpose"]
del df_credit["Sex"]
del df_credit["Housing"]
del df_credit["Age_cat"]

# %% [markdown]
# ## **Correlation**

# %%
plt.figure(figsize=(14,12))
sns.heatmap(df_credit.astype(float).corr(),linewidths=0.1,vmax=1.0, 
            square=True,  linecolor='white', annot=True)
plt.show()
